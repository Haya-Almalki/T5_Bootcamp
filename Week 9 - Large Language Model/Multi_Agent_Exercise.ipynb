# %% [markdown]
# # Exercise: Building a Multi-Agent System
#
# In this exercise, you will create a simple multi-agent system where two agents collaborate to accomplish a common goal. The first agent will conduct research on a topic, and the second agent will summarize the research.
#
# Follow the steps below to complete the exercise.
#
# ---
# ### Step 1: Install the Required Libraries
#
# Make sure the necessary libraries are installed using the following command:

# %%
# %%capture
# !pip install crewai langchain langchain-community langchain_groq

# %% [markdown]
# ---
# ### Step 2: Import the Necessary Libraries
#
# You will need to import the relevant libraries to create and manage your agents. Fill in the missing parts of the code below:

# %%
from crewai import Agent, Task, Crew
from langchain_groq import ChatGroq
import os

# %%
os.environ["GROQ_API_KEY"] = "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"

# %% [markdown]
# ---
# ### Step 3: Create Agents
#
# Now, define the two agents. **Agent 1** will handle research, and **Agent 2** will summarize the research.
#
# Fill in the code below to create the agents:

# %%
llm = ChatGroq(
    model="groq/llama-3.1-70b-versatile",
    temperature=0.7,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

# %%
#Agent 1 will handle research
researcher = Agent(
    llm=llm,
    role="Professional Researcher",
    goal="Research about Data science.",
    backstory="You are an experienced researcher about data science.",
    allow_delegation=False,
    verbose=1,  # Enables detailed logging
)

# %%
#Agent 2 will summarize the research
summarizer = Agent(
    llm=llm,
    role="Summarizer",
    goal="Summarize the research of Data science",
    backstory="You are an experienced in summarized the reseache about data science in simple way",
    allow_delegation=False,
    verbose=1
)

# %% [markdown]
# ---
# ### Step 4: Execute the Multi-Agent System
#
# Finally, run the system to allow the agents to collaborate and complete their tasks.

# %%
# Task1: Reasearch:
task1 = Task(
    description="Conduct research on Data science and explain the key concepts.",
    expected_output="A detailed research file about the concepts of data science.",
    output_file="final_research.txt",
    agent=researcher,
)

# %%
# task 2: summarize
task2 = Task(
    description="Summarize the result from the reseach of data science.",
    expected_output="A summary file of the research of data science.",
    output_file="final_summary.txt",
    agent=summarizer,
    input_file="final_research.txt",
)

# %%
crew = Crew(
    agents=[researcher, summarizer],
    tasks=[task1, task2],
    verbose=1
)
print(crew.kickoff())
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# # Agent: Professional Researcher
# ## Task: Conduct research on Data science and explain the key concepts.
#
#
# # Agent: Professional Researcher
# ## Final Answer:
# Data Science Concepts Research File
#
# Table of Contents
# -----------------
#
# 1. [Introduction to Data Science](#introduction-to-data-science)
# 2. [Key Concepts in Data Science](#key-concepts-in-data-science)
# 3. [Data Science Process](#data-science-process)
# 4. [Data Preprocessing](#data-preprocessing)
# 5. [Data Visualization](#data-visualization)
# 6. [Machine Learning](#machine-learning)
# 7. [Deep Learning](#deep-learning)
# 8. [Data Mining](#data-mining)
# 9. [Big Data](#big-data)
# 10. [Data Science Tools and Technologies](#data-science-tools-and-technologies)
#
# Introduction to Data Science
# -----------------------------
#
# Data science is a field that combines aspects of computer science, statistics, and domain-specific knowledge to extract insights from data. It involves using various techniques, such as machine learning, data visualization, and data preprocessing, to analyze and interpret data.
#
# Key Concepts in Data Science
# -----------------------------
#
# 1. **Data**: The raw material of data science, which can be in the form of numbers, text, images, or videos.
# 2. **Data Sources**: Where the data comes from, such as databases, APIs, or files.
# 3. **Data Preparation**: The process of cleaning, transforming, and formatting the data for analysis.
# 4. **Data Analysis**: The process of using statistical and mathematical techniques to extract insights from the data.
# 5. **Data Visualization**: The process of communicating insights and patterns in the data through visual representations.
# 6. **Machine Learning**: A subset of artificial intelligence that involves training models on data to make predictions or decisions.
# 7. **Deep Learning**: A subset of machine learning that involves using neural networks to analyze data.
#
# Data Science Process
# --------------------
#
# The data science process involves the following steps:
#
# 1. **Problem Definition**: Defining the problem or question to be answered.
# 2. **Data Collection**: Gathering the data from various sources.
# 3. **Data Preprocessing**: Cleaning, transforming, and formatting the data.
# 4. **Data Analysis**: Using statistical and mathematical techniques to extract insights from the data.
# 5. **Data Visualization**: Communicating insights and patterns in the data through visual representations.
# 6. **Modeling**: Training models on the data to make predictions or decisions.
# 7. **Evaluation**: Evaluating the performance of the models.
# 8. **Deployment**: Deploying the models in a production environment.
#
# Data Preprocessing
# ------------------
#
# Data preprocessing involves the following steps:
#
# 1. **Data Cleaning**: Handling missing values and outliers.
# 2. **Data Transformation**: Converting data from one format to another.
# 3. **Data Reduction**: Reducing the size of the data by removing unnecessary variables or observations.
# 4. **Data Integration**: Combining data from multiple sources.
#
# Data Visualization
# ------------------
#
# Data visualization involves using visual representations to communicate insights and patterns in the data. Common data visualization tools include:
#
# 1. **Matplotlib**: A Python library for creating static and interactive visualizations.
# 2. **Seaborn**: A Python library for creating informative and attractive statistical graphics.
# 3. **Tableau**: A data visualization platform for creating interactive dashboards.
#
# Machine Learning
# ----------------
#
# Machine learning involves training models on data to make predictions or decisions. Common machine learning algorithms include:
#
# 1. **Linear Regression**: A linear model for predicting continuous outcomes.
# 2. **Logistic Regression**: A linear model for predicting binary outcomes.
# 3. **Decision Trees**: A tree-based model for classification and regression tasks.
# 4. **Random Forests**: An ensemble model for classification and regression tasks.
#
# Deep Learning
# -------------
#
# Deep learning involves using neural networks to analyze data. Common deep learning architectures include:
#
# 1. **Convolutional Neural Networks (CNNs)**: A neural network for image and video analysis.
# 2. **Recurrent Neural Networks (RNNs)**: A neural network for sequential data analysis.
# 3. **Generative Adversarial Networks (GANs)**: A neural network for generating synthetic data.
#
# Data Mining
# ------------
#
# Data mining involves discovering patterns and relationships in large datasets. Common data mining techniques include:
#
# 1. **Association Rule Learning**: Discovering patterns in transactional data.
# 2. **Clustering**: Grouping similar observations together.
# 3. **Classification**: Predicting a categorical outcome.
#
# Big Data
# ---------
#
# Big data refers to large and complex datasets that require specialized tools and techniques to analyze. Common big data technologies include:
#
# 1. **Hadoop**: A distributed computing framework for processing large datasets.
# 2. **Spark**: A fast and general-purpose computing engine for processing large datasets.
# 3. **NoSQL Databases**: Databases designed for handling large amounts of unstructured data.
#
# Data Science Tools and Technologies
# -------------------------------------
#
# 1. **Python**: A programming language widely used in data science.
# 2. **R**: A programming language widely used in data science.
# 3. **SQL**: A language for managing and analyzing relational databases.
# 4. **Excel**: A spreadsheet software for data analysis and visualization.
# 5. **Tableau**: A data visualization platform for creating interactive dashboards.
# 6. **Kaggle**: A platform for competitions and hosting datasets.
# 7. **Jupyter Notebook**: A web-based interactive environment for data science.
# 8. **TensorFlow**: An open-source machine learning library.
# 9. **PyTorch**: An open-source machine learning library.
#
# Conclusion
# ----------
#
# Data science is a field that involves using various techniques, such as machine learning, data visualization, and data preprocessing, to extract insights from data. The key concepts in data science include data, data sources, data preparation, data analysis, data visualization, machine learning, and deep learning. The data science process involves defining a problem, collecting data, preprocessing the data, analyzing the data, visualizing the data, modeling, evaluating, and deploying. Common tools and technologies used in data science include Python, R, SQL, Excel, Tableau, Kaggle, Jupyter Notebook, TensorFlow, and PyTorch.
# # Agent: Summarizer
# ## Task: Summarize the result from the reseach of data science.
#
#
# # Agent: Summarizer
# ## Final Answer:
# Data Science Concepts Research File
#
# Table of Contents
# -----------------
#
# 1. [Introduction to Data Science](#introduction-to-data-science)
# 2. [Key Concepts in Data Science](#key-concepts-in-data-science)
# 3. [Data Science Process](#data-science-process)
# 4. [Data Preprocessing](#data-preprocessing)
# 5. [Data Visualization](#data-visualization)
# 6. [Machine Learning](#machine-learning)
# 7. [Deep Learning](#deep-learning)
# 8. [Data Mining](#data-mining)
# 9. [Big Data](#big-data)
# 10. [Data Science Tools and Technologies](#data-science-tools-and-technologies)
#
# Introduction to Data Science
# -----------------------------
#
# Data science is a field that combines aspects of computer science, statistics, and domain-specific knowledge to extract insights from data. It involves using various techniques, such as machine learning, data visualization, and data preprocessing, to analyze and interpret data.
#
# Key Concepts in Data Science
# -----------------------------
#
# 1. **Data**: The raw material of data science, which can be in the form of numbers, text, images, or videos.
# 2. **Data Sources**: Where the data comes from, such as databases, APIs, or files.
# 3. **Data Preparation**: The process of cleaning, transforming, and formatting the data for analysis.
# 4. **Data Analysis**: The process of using statistical and mathematical techniques to extract insights from the data.
# 5. **Data Visualization**: The process of communicating insights and patterns in the data through visual representations.
# 6. **Machine Learning**: A subset of artificial intelligence that involves training models on data to make predictions or decisions.
# 7. **Deep Learning**: A subset of machine learning that involves using neural networks to analyze data.
#
# Data Science Process
# --------------------
#
# The data science process involves the following steps:
#
# 1. **Problem Definition**: Defining the problem or question to be answered.
# 2. **Data Collection**: Gathering the data from various sources.
# 3. **Data Preprocessing**: Cleaning, transforming, and formatting the data.
# 4. **Data Analysis**: Using statistical and mathematical techniques to extract insights from the data.
# 5. **Data Visualization**: Communicating insights and patterns in the data through visual representations.
# 6. **Modeling**: Training models on the data to make predictions or decisions.
# 7. **Evaluation**: Evaluating the performance of the models.
# 8. **Deployment**: Deploying the models in a production environment.
#
# Data Preprocessing
# ------------------
#
# Data preprocessing involves the following steps:
#
# 1. **Data Cleaning**: Handling missing values and outliers.
# 2. **Data Transformation**: Converting data from one format to another.
# 3. **Data Reduction**: Reducing the size of the data by removing unnecessary variables or observations.
# 4. **Data Integration**: Combining data from multiple sources.
#
# Data Visualization
# ------------------
#
# Data visualization involves using visual representations to communicate insights and patterns in the data. Common data visualization tools include:
#
# 1. **Matplotlib**: A Python library for creating static and interactive visualizations.
# 2. **Seaborn**: A Python library for creating informative and attractive statistical graphics.
# 3. **Tableau**: A data visualization platform for creating interactive dashboards.
#
# Machine Learning
# ----------------
#
# Machine learning involves training models on data to make predictions or decisions. Common machine learning algorithms include:
#
# 1. **Linear Regression**: A linear model for predicting continuous outcomes.
# 2. **Logistic Regression**: A linear model for predicting binary outcomes.
# 3. **Decision Trees**: A tree-based model for classification and regression tasks.
# 4. **Random Forests**: An ensemble model for classification and regression tasks.
#
# Deep Learning
# -------------
#
# Deep learning involves using neural networks to analyze data. Common deep learning architectures include:
#
# 1. **Convolutional Neural Networks (CNNs)**: A neural network for image and video analysis.
# 2. **Recurrent Neural Networks (RNNs)**: A neural network for sequential data analysis.
# 3. **Generative Adversarial Networks (GANs)**: A neural network for generating synthetic data.
#
# Data Mining
# ------------
#
# Data mining involves discovering patterns and relationships in large datasets. Common data mining techniques include:
#
# 1. **Association Rule Learning**: Discovering patterns in transactional data.
# 2. **Clustering**: Grouping similar observations together.
# 3. **Classification**: Predicting a categorical outcome.
#
# Big Data
# ---------
#
# Big data refers to large and complex datasets that require specialized tools and techniques to analyze. Common big data technologies include:
#
# 1. **Hadoop**: A distributed computing framework for processing large datasets.
# 2. **Spark**: A fast and general-purpose computing engine for processing large datasets.
# 3. **NoSQL Databases**: Databases designed for handling large amounts of unstructured data.
#
# Data Science Tools and Technologies
# -------------------------------------
#
# 1. **Python**: A programming language widely used in data science.
# 2. **R**: A programming language widely used in data science.
# 3. **SQL**: A language for managing and analyzing relational databases.
# 4. **Excel**: A spreadsheet software for data analysis and visualization.
# 5. **Tableau**: A data visualization platform for creating interactive dashboards.
# 6. **Kaggle**: A platform for competitions and hosting datasets.
# 7. **Jupyter Notebook**: A web-based interactive environment for data science.
# 8. **TensorFlow**: An open-source machine learning library.
# 9. **PyTorch**: An open-source machine learning library.
#
# Conclusion
# ----------
#
# Data science is a field that involves using various techniques, such as machine learning, data visualization, and data preprocessing, to extract insights from data. The key concepts in data science include data, data sources, data preparation, data analysis, data visualization, machine learning, and deep learning. The data science process involves defining a problem, collecting data, preprocessing the data, analyzing the data, visualizing the data, modeling, evaluating, and deploying. Common tools and technologies used in data science include Python, R, SQL, Excel, Tableau, Kaggle, Jupyter Notebook, TensorFlow, and PyTorch.
# Data Science Concepts Research File
#
# Table of Contents
# -----------------
#
# 1. [Introduction to Data Science](#introduction-to-data-science)
# 2. [Key Concepts in Data Science](#key-concepts-in-data-science)
# 3. [Data Science Process](#data-science-process)
# 4. [Data Preprocessing](#data-preprocessing)
# 5. [Data Visualization](#data-visualization)
# 6. [Machine Learning](#machine-learning)
# 7. [Deep Learning](#deep-learning)
# 8. [Data Mining](#data-mining)
# 9. [Big Data](#big-data)
# 10. [Data Science Tools and Technologies](#data-science-tools-and-technologies)
#
# Introduction to Data Science
# -----------------------------
#
# Data science is a field that combines aspects of computer science, statistics, and domain-specific knowledge to extract insights from data. It involves using various techniques, such as machine learning, data visualization, and data preprocessing, to analyze and interpret data.
#
# Key Concepts in Data Science
# -----------------------------
#
# 1. **Data**: The raw material of data science, which can be in the form of numbers, text, images, or videos.
# 2. **Data Sources**: Where the data comes from, such as databases, APIs, or files.
# 3. **Data Preparation**: The process of cleaning, transforming, and formatting the data for analysis.
# 4. **Data Analysis**: The process of using statistical and mathematical techniques to extract insights from the data.
# 5. **Data Visualization**: The process of communicating insights and patterns in the data through visual representations.
# 6. **Machine Learning**: A subset of artificial intelligence that involves training models on data to make predictions or decisions.
# 7. **Deep Learning**: A subset of machine learning that involves using neural networks to analyze data.
#
# Data Science Process
# --------------------
#
# The data science process involves the following steps:
#
# 1. **Problem Definition**: Defining the problem or question to be answered.
# 2. **Data Collection**: Gathering the data from various sources.
# 3. **Data Preprocessing**: Cleaning, transforming, and formatting the data.
# 4. **Data Analysis**: Using statistical and mathematical techniques to extract insights from the data.
# 5. **Data Visualization**: Communicating insights and patterns in the data through visual representations.
# 6. **Modeling**: Training models on the data to make predictions or decisions.
# 7. **Evaluation**: Evaluating the performance of the models.
# 8. **Deployment**: Deploying the models in a production environment.
#
# Data Preprocessing
# ------------------
#
# Data preprocessing involves the following steps:
#
# 1. **Data Cleaning**: Handling missing values and outliers.
# 2. **Data Transformation**: Converting data from one format to another.
# 3. **Data Reduction**: Reducing the size of the data by removing unnecessary variables or observations.
# 4. **Data Integration**: Combining data from multiple sources.
#
# Data Visualization
# ------------------
#
# Data visualization involves using visual representations to communicate insights and patterns in the data. Common data visualization tools include:
#
# 1. **Matplotlib**: A Python library for creating static and interactive visualizations.
# 2. **Seaborn**: A Python library for creating informative and attractive statistical graphics.
# 3. **Tableau**: A data visualization platform for creating interactive dashboards.
#
# Machine Learning
# ----------------
#
# Machine learning involves training models on data to make predictions or decisions. Common machine learning algorithms include:
#
# 1. **Linear Regression**: A linear model for predicting continuous outcomes.
# 2. **Logistic Regression**: A linear model for predicting binary outcomes.
# 3. **Decision Trees**: A tree-based model for classification and regression tasks.
# 4. **Random Forests**: An ensemble model for classification and regression tasks.
#
# Deep Learning
# -------------
#
# Deep learning involves using neural networks to analyze data. Common deep learning architectures include:
#
# 1. **Convolutional Neural Networks (CNNs)**: A neural network for image and video analysis.
# 2. **Recurrent Neural Networks (RNNs)**: A neural network for sequential data analysis.
# 3. **Generative Adversarial Networks (GANs)**: A neural network for generating synthetic data.
#
# Data Mining
# ------------
#
# Data mining involves discovering patterns and relationships in large datasets. Common data mining techniques include:
#
# 1. **Association Rule Learning**: Discovering patterns in transactional data.
# 2. **Clustering**: Grouping similar observations together.
# 3. **Classification**: Predicting a categorical outcome.
#
# Big Data
# ---------
#
# Big data refers to large and complex datasets that require specialized tools and techniques to analyze. Common big data technologies include:
#
# 1. **Hadoop**: A distributed computing framework for processing large datasets.
# 2. **Spark**: A fast and general-purpose computing engine for processing large datasets.
# 3. **NoSQL Databases**: Databases designed for handling large amounts of unstructured data.
#
# Data Science Tools and Technologies
# -------------------------------------
#
# 1. **Python**: A programming language widely used in data science.
# 2. **R**: A programming language widely used in data science.
# 3. **SQL**: A language for managing and analyzing relational databases.
# 4. **Excel**: A spreadsheet software for data analysis and visualization.
# 5. **Tableau**: A data visualization platform for creating interactive dashboards.
# 6. **Kaggle**: A platform for competitions and hosting datasets.
# 7. **Jupyter Notebook**: A web-based interactive environment for data science.
# 8. **TensorFlow**: An open-source machine learning library.
# 9. **PyTorch**: An open-source machine learning library.
#
# Conclusion
# ----------
#
# Data science is a field that involves using various techniques, such as machine learning, data visualization, and data preprocessing, to extract insights from data. The key concepts in data science include data, data sources, data preparation, data analysis, data visualization, machine learning, and deep learning. The data science process involves defining a problem, collecting data, preprocessing the data, analyzing the data, visualizing the data, modeling, evaluating, and deploying. Common tools and technologies used in data science include Python, R, SQL, Excel, Tableau, Kaggle, Jupyter Notebook, TensorFlow, and PyTorch.
